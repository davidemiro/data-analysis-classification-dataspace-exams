# %% [markdown]
# <a href="https://colab.research.google.com/github/davidemiro/ProjectDataSpace/blob/main/llama_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# First let's update all the packages to the latest ones with the following command
# !sudo apt update -qq

# Now we want to install some prerequisite packages which will let us use HTTPS over apt
# !sudo apt install apt-transport-https ca-certificates curl software-properties-common -qq

# After that we will add the GPG key for the official Docker repository to the system
# !curl -fsSL https://download.docker.com/linux/ubuntu/gpg | sudo apt-key add -

# We will add the Docker repository to our APT sources
# !sudo add-apt-repository "deb [arch=amd64] https://download.docker.com/linux/ubuntu bionic stable"

# Next let's update the package database with our newly added Docker package repo
# !sudo apt update -qq

# Finally lets install docker with the below command
# !sudo apt install docker-ce

# Lets check that docker is running
# !docker
# Out:
# 16 packages can be upgraded. Run 'apt list --upgradable' to see them.
# ca-certificates is already the newest version (20230311ubuntu0.22.04.1).
# curl is already the newest version (7.81.0-1ubuntu1.13).
# software-properties-common is already the newest version (0.99.22.7).
# The following NEW packages will be installed:
#   apt-transport-https
# 0 upgraded, 1 newly installed, 0 to remove and 16 not upgraded.
# Need to get 1,510 B of archives.
# After this operation, 169 kB of additional disk space will be used.
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package apt-transport-https.
# (Reading database ... 120893 files and directories currently installed.)
# Preparing to unpack .../apt-transport-https_2.4.10_all.deb ...
# Unpacking apt-transport-https (2.4.10) ...
# Setting up apt-transport-https (2.4.10) ...
# Warning: apt-key is deprecated. Manage keyring files in trusted.gpg.d instead (see apt-key(8)).
# OK
# Repository: 'deb [arch=amd64] https://download.docker.com/linux/ubuntu bionic stable'
# Description:
# Archive for codename: bionic components: stable
# More info: https://download.docker.com/linux/ubuntu
# Adding repository.
# Press [ENTER] to continue or Ctrl-c to cancel.Traceback (most recent call last):
#   File "/usr/bin/add-apt-repository", line 132, in prompt_user
#     input(_("Press [ENTER] to continue or Ctrl-c to cancel."))
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/bin/add-apt-repository", line 364, in <module>
#     sys.exit(0 if addaptrepo.main() else 1)
#   File "/usr/bin/add-apt-repository", line 352, in main
#     self.prompt_user_shortcut(shortcut)
#   File "/usr/bin/add-apt-repository", line 152, in prompt_user_shortcut
#     self.prompt_user()
#   File "/usr/bin/add-apt-repository", line 134, in prompt_user
#     print(_("Aborted."))
#   File "/usr/lib/python3.10/gettext.py", line 756, in gettext
#     def gettext(message):
# KeyboardInterrupt
# ^C
# 16 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Package docker-ce is not available, but is referred to by another package.
# This may mean that the package is missing, has been obsoleted, or
# is only available from another source
#
# E: Package 'docker-ce' has no installation candidate
# /bin/bash: line 1: docker: command not found

# %%
# !pip install -q accelerate==0.21.0 peft==0.4.0 bitsandbytes==0.40.2 transformers==4.31.0 trl==0.4.7 dataset
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 4.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 MB 19.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 114.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.4/77.4 kB 9.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 70.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 30.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 113.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.3/519.3 kB 50.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 87.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.4/225.4 kB 24.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 10.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 13.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 22.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 17.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.4.49 which is incompatible.

# %%
import os
import torch
from datasets import load_dataset
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    HfArgumentParser,
    TrainingArguments,
    pipeline,
    logging,
)
from peft import LoraConfig, PeftModel
from trl import SFTTrainer

# %%
# Load dataset (you can process it here)
dataset_name = "databricks/databricks-dolly-15k"
dataset = load_dataset(dataset_name)
dataset_imb = load_dataset("imdb")

print(dataset_imb)
print(dataset)




# ['instruction', 'context', 'response', 'category']
# Tokenize the dataset
def to_llama_2_prompt_format(input):

    llama_2_prompt_format =["<s>[INST] <<SYS>>\n{}\n<</SYS>>\n{} [/INST] {} </s>".format(context,instruction,response) for context,instruction,response in zip(input["context"],input["instruction"],input["response"])]
    return {"prompt": llama_2_prompt_format}




llama_2_prompt_format_datasets = dataset.map(to_llama_2_prompt_format, batched=True)

print(llama_2_prompt_format_datasets)
print(llama_2_prompt_format_datasets["train"]["prompt"][0])
# Out:
# Downloading readme:   0%|          | 0.00/8.20k [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/13.1M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Downloading builder script:   0%|          | 0.00/4.31k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/2.17k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/7.59k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/84.1M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Generating unsupervised split:   0%|          | 0/50000 [00:00<?, ? examples/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-225e83c476a8> in <cell line: 4>()
#       2 dataset_name = "databricks/databricks-dolly-15k"
#       3 dataset = load_dataset(dataset_name)
# ----> 4 dataset_imb = load_dataset("imdb")
#       5
#       6 print(dataset_imb)
#
# /usr/local/lib/python3.10/dist-packages/datasets/load.py in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, ignore_verifications, keep_in_memory, save_infos, revision, token, use_auth_token, task, streaming, num_proc, storage_options, **config_kwargs)
#    2134
#    2135     # Download and prepare data
# -> 2136     builder_instance.download_and_prepare(
#    2137         download_config=download_config,
#    2138         download_mode=download_mode,
#
# /usr/local/lib/python3.10/dist-packages/datasets/builder.py in download_and_prepare(self, output_dir, download_config, download_mode, verification_mode, ignore_verifications, try_from_hf_gcs, dl_manager, base_path, use_auth_token, file_format, max_shard_size, num_proc, storage_options, **download_and_prepare_kwargs)
#     952                         if num_proc is not None:
#     953                             prepare_split_kwargs["num_proc"] = num_proc
# --> 954                         self._download_and_prepare(
#     955                             dl_manager=dl_manager,
#     956                             verification_mode=verification_mode,
#
# /usr/local/lib/python3.10/dist-packages/datasets/builder.py in _download_and_prepare(self, dl_manager, verification_mode, **prepare_splits_kwargs)
#    1715
#    1716     def _download_and_prepare(self, dl_manager, verification_mode, **prepare_splits_kwargs):
# -> 1717         super()._download_and_prepare(
#    1718             dl_manager,
#    1719             verification_mode,
#
# /usr/local/lib/python3.10/dist-packages/datasets/builder.py in _download_and_prepare(self, dl_manager, verification_mode, **prepare_split_kwargs)
#    1047             try:
#    1048                 # Prepare split will record examples associated to the split
# -> 1049                 self._prepare_split(split_generator, **prepare_split_kwargs)
#    1050             except OSError as e:
#    1051                 raise OSError(
#
# /usr/local/lib/python3.10/dist-packages/datasets/builder.py in _prepare_split(self, split_generator, check_duplicate_keys, file_format, num_proc, max_shard_size)
#    1553             job_id = 0
#    1554             with pbar:
# -> 1555                 for job_id, done, content in self._prepare_split_single(
#    1556                     gen_kwargs=gen_kwargs, job_id=job_id, **_prepare_split_args
#    1557                 ):
#
# /usr/local/lib/python3.10/dist-packages/datasets/builder.py in _prepare_split_single(self, gen_kwargs, fpath, file_format, max_shard_size, split_info, check_duplicate_keys, job_id)
#    1674             try:
#    1675                 _time = time.time()
# -> 1676                 for key, record in generator:
#    1677                     if max_shard_size is not None and writer._num_bytes > max_shard_size:
#    1678                         num_examples, num_bytes = writer.finalize()
#
# ~/.cache/huggingface/modules/datasets_modules/datasets/imdb/d613c88cf8fa3bab83b4ded3713f1f74830d1100e171db75bbddb80b3345c9c0/imdb.py in _generate_examples(self, files, split, labeled)
#     106                         yield path, {"text": f.read().decode("utf-8"), "label": label}
#     107         else:
# --> 108             for path, f in files:
#     109                 if path.startswith(f"aclImdb/{split}"):
#     110                     if path.split("/")[2] == "unsup":
#
# /usr/local/lib/python3.10/dist-packages/datasets/download/download_manager.py in __iter__(self)
#     156
#     157     def __iter__(self):
# --> 158         yield from self.generator(*self.args, **self.kwargs)
#     159
#     160
#
# /usr/local/lib/python3.10/dist-packages/datasets/download/download_manager.py in _iter_from_path(cls, urlpath)
#     209                 yield from cls._iter_zip(f)
#     210             else:
# --> 211                 yield from cls._iter_tar(f)
#     212
#     213     @classmethod
#
# /usr/local/lib/python3.10/dist-packages/datasets/download/download_manager.py in _iter_tar(f)
#     165     def _iter_tar(f):
#     166         stream = tarfile.open(fileobj=f, mode="r|*")
# --> 167         for tarinfo in stream:
#     168             file_path = tarinfo.name
#     169             if not tarinfo.isreg():
#
# /usr/lib/python3.10/tarfile.py in __iter__(self)
#    2735                 tarinfo = self.members[index]
#    2736             elif not self._loaded:
# -> 2737                 tarinfo = self.next()
#    2738                 if not tarinfo:
#    2739                     self._loaded = True
#
# /usr/lib/python3.10/tarfile.py in next(self)
#    2593         while True:
#    2594             try:
# -> 2595                 tarinfo = self.tarinfo.fromtarfile(self)
#    2596             except EOFHeaderError as e:
#    2597                 if self.ignore_zeros:
#
# /usr/lib/python3.10/tarfile.py in fromtarfile(cls, tarfile)
#    1283            tarfile.
#    1284         """
# -> 1285         buf = tarfile.fileobj.read(BLOCKSIZE)
#    1286         obj = cls.frombuf(buf, tarfile.encoding, tarfile.errors)
#    1287         obj.offset = tarfile.fileobj.tell() - BLOCKSIZE
#
# /usr/lib/python3.10/tarfile.py in read(self, size)
#     524         """Return the next size number of bytes from the stream."""
#     525         assert size is not None
# --> 526         buf = self._read(size)
#     527         self.pos += len(buf)
#     528         return buf
#
# KeyboardInterrupt:

# %%
#Llama models Hugging Face



# The model that you want to train from the Hugging Face hub
model_name = "meta-llama/Llama-2-7b-chat-hf"

# The instruction dataset to use
dataset_name = "databricks/databricks-dolly-15k"

# Fine-tuned model name
new_model = "llama-2-7b-neurips_dm"

################################################################################
# QLoRA parameters
################################################################################

# LoRA attention dimension
lora_r = 64

# Alpha parameter for LoRA scaling
lora_alpha = 16

# Dropout probability for LoRA layers
lora_dropout = 0.1

################################################################################
# bitsandbytes parameters
################################################################################

# Activate 4-bit precision base model loading
use_4bit = True

# Compute dtype for 4-bit base models
bnb_4bit_compute_dtype = "float16"

# Quantization type (fp4 or nf4)
bnb_4bit_quant_type = "nf4"

# Activate nested quantization for 4-bit base models (double quantization)
use_nested_quant = False

################################################################################
# TrainingArguments parameters
################################################################################

# Output directory where the model predictions and checkpoints will be stored
output_dir = "./results"

# Number of training epochs
num_train_epochs = 1

# Enable fp16/bf16 training (set bf16 to True with an A100)
fp16 = False
bf16 = False

# Batch size per GPU for training
per_device_train_batch_size = 4

# Batch size per GPU for evaluation
per_device_eval_batch_size = 4

# Number of update steps to accumulate the gradients for
gradient_accumulation_steps = 1

# Enable gradient checkpointing
gradient_checkpointing = True

# Maximum gradient normal (gradient clipping)
max_grad_norm = 0.3

# Initial learning rate (AdamW optimizer)
learning_rate = 2e-4

# Weight decay to apply to all layers except bias/LayerNorm weights
weight_decay = 0.001

# Optimizer to use
optim = "paged_adamw_32bit"

# Learning rate schedule (constant a bit better than cosine)
lr_scheduler_type = "constant"

# Number of training steps (overrides num_train_epochs)
max_steps = -1

# Ratio of steps for a linear warmup (from 0 to learning rate)
warmup_ratio = 0.03

# Group sequences into batches with same length
# Saves memory and speeds up training considerably
group_by_length = True

# Save checkpoint every X updates steps
save_steps = 25

# Log every X updates steps
logging_steps = 25

################################################################################
# SFT parameters
################################################################################

# Maximum sequence length to use
max_seq_length = None

# Pack multiple short examples in the same input sequence to increase efficiency
packing = False

# Load the entire model on the GPU 0
device_map = {"": 0}

#
################################################################################
# Hugging face access token
################################################################################
access_token = "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"

# %%
# Load dataset (you can process it here)
dataset = load_dataset(dataset_name, split="train")



# Tokenize the dataset

# LLaMa 2 prompt
"""
<s>[INST] <<SYS>>
System Prompt: context for the LLM (optional)
<</SYS>>
User Prompt: Instruction (required) [/INST] Model answare (required) </s>

"""
def to_llama_2_prompt_format(input):

    llama_2_prompt_format =["<s>[INST] <<SYS>>\n{}\n<</SYS>>\n{} [/INST] {} </s>".format(context,instruction,response) for context,instruction,response in zip(input["context"],input["instruction"],input["response"])]
    return {"prompt": llama_2_prompt_format}




llama_2_prompt_format_datasets = dataset.map(to_llama_2_prompt_format, batched=True)









# Load tokenizer and model with QLoRA configuration
compute_dtype = getattr(torch, bnb_4bit_compute_dtype)

bnb_config = BitsAndBytesConfig(
    load_in_4bit=use_4bit,
    bnb_4bit_quant_type=bnb_4bit_quant_type,
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=use_nested_quant,
)

# Check GPU compatibility with bfloat16
if compute_dtype == torch.float16 and use_4bit:
    major, _ = torch.cuda.get_device_capability()
    if major >= 8:
        print("=" * 80)
        print("Your GPU supports bfloat16: accelerate training with bf16=True")
        print("=" * 80)

# Load base model
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    device_map=device_map,
    use_auth_token=access_token
)
model.config.use_cache = False
model.config.pretraining_tp = 1

# Load LLaMA tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True, use_auth_token=access_token)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right" # Fix weird overflow issue with fp16 training

# Load LoRA configuration
peft_config = LoraConfig(
    lora_alpha=lora_alpha,
    lora_dropout=lora_dropout,
    r=lora_r,
    bias="none",
    task_type="CAUSAL_LM",
)

# Set training parameters
training_arguments = TrainingArguments(
    output_dir=output_dir,
    num_train_epochs=num_train_epochs,
    per_device_train_batch_size=per_device_train_batch_size,
    gradient_accumulation_steps=gradient_accumulation_steps,
    optim=optim,
    save_steps=save_steps,
    logging_steps=logging_steps,
    learning_rate=learning_rate,
    weight_decay=weight_decay,
    fp16=fp16,
    bf16=bf16,
    max_grad_norm=max_grad_norm,
    max_steps=max_steps,
    warmup_ratio=warmup_ratio,
    group_by_length=group_by_length,
    lr_scheduler_type=lr_scheduler_type,
    report_to="tensorboard"
)

# Set supervised fine-tuning parameters
trainer = SFTTrainer(
    model=model,
    train_dataset=llama_2_prompt_format_datasets,
    peft_config=peft_config,
    dataset_text_field="prompt",
    max_seq_length=max_seq_length,
    tokenizer=tokenizer,
    args=training_arguments,
    packing=packing,
)

# Train model
trainer.train()

# Save trained model
trainer.model.save_pretrained(new_model)
# Out:
# Downloading readme:   0%|          | 0.00/8.20k [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/13.1M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/15011 [00:00<?, ? examples/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:2193: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# Downloading (…)fetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# Downloading (…)of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/776 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1714: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# Downloading tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/peft/utils/other.py:102: FutureWarning: prepare_model_for_int8_training is deprecated and will be removed in a future version. Use prepare_model_for_kbit_training instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:159: UserWarning: You didn't pass a `max_seq_length` argument to the SFTTrainer, this will default to 1024
#   warnings.warn(
# Map:   0%|          | 0/15011 [00:00<?, ? examples/s]
# You're using a LlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='201' max='3753' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 201/3753 10:12 < 3:02:09, 0.32 it/s, Epoch 0.05/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>25</td>
#       <td>1.929600</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.345100</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>1.620600</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.289700</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>1.486700</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>1.248500</td>
#     </tr>
#     <tr>
#       <td>175</td>
#       <td>1.485800</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
from huggingface_hub import create_repo
create_repo("mirodavide/Llama-2-7b-chat-hf-finetune",private=True,token=access_token)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py in hf_raise_for_status(response, endpoint_name)
#     260     try:
# --> 261         response.raise_for_status()
#     262     except HTTPError as e:
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
#    1020         if http_error_msg:
# -> 1021             raise HTTPError(http_error_msg, response=self)
#    1022
#
# HTTPError: 403 Client Error: Forbidden for url: https://huggingface.co/api/repos/create
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# <ipython-input-28-f64f7b262659> in <cell line: 2>()
#       1 from huggingface_hub import create_repo
# ----> 2 create_repo("mirodavide/Llama-2-7b-chat-hf-finetune",private=True,token=access_token)
#       3
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     116             kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
#     117
# --> 118         return fn(*args, **kwargs)
#     119
#     120     return _inner_fn  # type: ignore
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/hf_api.py in create_repo(self, repo_id, token, private, repo_type, exist_ok, space_sdk, space_hardware)
#    2306
#    2307         try:
# -> 2308             hf_raise_for_status(r)
#    2309         except HTTPError as err:
#    2310             if exist_ok and err.response.status_code == 409:
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py in hf_raise_for_status(response, endpoint_name)
#     301         # Convert `HTTPError` into a `HfHubHTTPError` to display request information
#     302         # as well (request id and/or server error message)
# --> 303         raise HfHubHTTPError(str(e), response=response) from e
#     304
#     305
#
# HfHubHTTPError: 403 Client Error: Forbidden for url: https://huggingface.co/api/repos/create (Request ID: Root=1-64e69dcf-79ff8f1e117c644f4d9b1225;789848c3-cb29-4f87-858f-a65a700c4d26)
#
# You don't have the rights to create a model under this namespace

# %% [markdown]
# # Evaluation

# %%
# !pip install crfm-helm
#!pip install --upgrade huggingface_hub
# Out:
# Output streaming troncato alle ultime 5000 righe.
#   Using cached boto3-1.26.6-py3-none-any.whl (132 kB)
# Collecting botocore<1.30.0,>=1.29.6 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.29.6-py3-none-any.whl (9.9 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.26.5-py3-none-any.whl (132 kB)
# Collecting botocore<1.30.0,>=1.29.5 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.29.5-py3-none-any.whl (9.9 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.26.4-py3-none-any.whl (132 kB)
# Collecting botocore<1.30.0,>=1.29.4 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.29.4-py3-none-any.whl (9.8 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.26.3-py3-none-any.whl (132 kB)
# Collecting botocore<1.30.0,>=1.29.3 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.29.3-py3-none-any.whl (9.8 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.26.2-py3-none-any.whl (132 kB)
# Collecting botocore<1.30.0,>=1.29.2 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.29.2-py3-none-any.whl (9.8 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.26.1-py3-none-any.whl (132 kB)
# Collecting botocore<1.30.0,>=1.29.1 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.29.1-py3-none-any.whl (9.8 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.26.0-py3-none-any.whl (132 kB)
# Collecting botocore<1.30.0,>=1.29.0 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.29.0-py3-none-any.whl (9.8 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.25.5-py3-none-any.whl (132 kB)
# Collecting botocore<1.29.0,>=1.28.5 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.28.5-py3-none-any.whl (9.3 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.25.4-py3-none-any.whl (132 kB)
# Collecting botocore<1.29.0,>=1.28.4 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.28.4-py3-none-any.whl (9.3 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.25.3-py3-none-any.whl (132 kB)
# Collecting botocore<1.29.0,>=1.28.3 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.28.3-py3-none-any.whl (9.3 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.25.2-py3-none-any.whl (132 kB)
# Collecting botocore<1.29.0,>=1.28.2 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.28.2-py3-none-any.whl (9.3 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.25.1-py3-none-any.whl (132 kB)
# Collecting botocore<1.29.0,>=1.28.1 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.28.1-py3-none-any.whl (9.3 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.25.0-py3-none-any.whl (132 kB)
# Collecting botocore<1.29.0,>=1.28.0 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.28.0-py3-none-any.whl (9.3 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.96-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.96 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.96-py3-none-any.whl (9.3 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.95-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.95 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.95-py3-none-any.whl (9.3 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.94-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.94 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.94-py3-none-any.whl (9.3 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.93-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.93 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.93-py3-none-any.whl (9.3 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.92-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.92 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.92-py3-none-any.whl (9.3 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.91-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.91 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.91-py3-none-any.whl (9.2 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.90-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.90 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.90-py3-none-any.whl (9.2 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.89-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.89 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.89-py3-none-any.whl (9.2 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.88-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.88 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.88-py3-none-any.whl (9.2 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.87-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.87 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.87-py3-none-any.whl (9.2 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.86-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.86 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.86-py3-none-any.whl (9.2 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.85-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.85 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.85-py3-none-any.whl (9.2 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.84-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.84 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.84-py3-none-any.whl (9.2 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.83-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.83 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.83-py3-none-any.whl (9.2 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.82-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.82 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.82-py3-none-any.whl (9.2 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.81-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.81 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.81-py3-none-any.whl (9.2 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.80-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.80 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.80-py3-none-any.whl (9.1 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.79-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.79 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.79-py3-none-any.whl (9.1 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.78-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.78 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.78-py3-none-any.whl (9.1 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.77-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.77 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.77-py3-none-any.whl (9.1 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.76-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.76 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.76-py3-none-any.whl (9.1 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.75-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.75 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.75-py3-none-any.whl (9.1 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.74-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.74 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.74-py3-none-any.whl (9.1 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.73-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.73 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.73-py3-none-any.whl (9.1 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.72-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.72 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.72-py3-none-any.whl (9.1 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.71-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.71 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.71-py3-none-any.whl (9.1 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.70-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.70 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.70-py3-none-any.whl (9.1 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.69-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.69 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.69-py3-none-any.whl (9.1 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.68-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.68 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.68-py3-none-any.whl (9.1 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.67-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.67 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.67-py3-none-any.whl (9.1 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.66-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.66 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.66-py3-none-any.whl (9.1 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.65-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.65 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.65-py3-none-any.whl (9.1 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.64-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.64 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.64-py3-none-any.whl (9.1 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.63-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.63 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.63-py3-none-any.whl (9.1 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.62-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.62 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.62-py3-none-any.whl (9.1 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.61-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.61 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.61-py3-none-any.whl (9.1 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.60-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.60 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.60-py3-none-any.whl (9.1 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.59-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.59 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.59-py3-none-any.whl (9.1 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.58-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.58 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.58-py3-none-any.whl (9.1 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.57-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.57 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.57-py3-none-any.whl (9.1 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.56-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.56 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.56-py3-none-any.whl (9.1 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.55-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.55 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.55-py3-none-any.whl (9.1 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.54-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.54 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.54-py3-none-any.whl (9.1 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.53-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.53 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.53-py3-none-any.whl (9.1 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.52-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.52 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.52-py3-none-any.whl (9.0 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.51-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.51 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.51-py3-none-any.whl (9.0 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.50-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.50 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.50-py3-none-any.whl (9.0 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.49-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.49 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.49-py3-none-any.whl (9.0 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.48-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.48 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.48-py3-none-any.whl (9.0 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.47-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.47 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.47-py3-none-any.whl (9.0 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.46-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.46 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.46-py3-none-any.whl (9.0 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.45-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.45 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.45-py3-none-any.whl (9.0 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.44-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.44 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.44-py3-none-any.whl (9.0 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.43-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.43 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.43-py3-none-any.whl (9.0 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.42-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.42 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.42-py3-none-any.whl (9.0 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.41-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.41 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.41-py3-none-any.whl (9.0 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.40-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.40 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.40-py3-none-any.whl (9.0 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.39-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.39 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.39-py3-none-any.whl (9.0 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.38-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.38 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.38-py3-none-any.whl (9.0 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.37-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.37 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.37-py3-none-any.whl (9.0 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.36-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.36 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.36-py3-none-any.whl (9.0 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.35-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.35 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.35-py3-none-any.whl (9.0 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.34-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.34 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.34-py3-none-any.whl (9.0 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.33-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.33 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.33-py3-none-any.whl (9.0 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.32-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.32 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.32-py3-none-any.whl (9.0 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.31-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.31 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.31-py3-none-any.whl (9.0 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.30-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.30 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.30-py3-none-any.whl (9.0 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.29-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.29 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.29-py3-none-any.whl (9.0 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.28-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.28 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.28-py3-none-any.whl (9.0 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.27-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.27 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.27-py3-none-any.whl (9.0 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.26-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.26 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.26-py3-none-any.whl (9.0 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.25-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.25 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.25-py3-none-any.whl (9.0 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.24-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.24 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.24-py3-none-any.whl (9.0 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.23-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.23 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.23-py3-none-any.whl (8.9 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.22-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.22 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.22-py3-none-any.whl (8.9 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.21-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.21 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.21-py3-none-any.whl (8.9 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.20-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.20 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.20-py3-none-any.whl (8.9 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.19-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.19 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.19-py3-none-any.whl (8.9 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.18-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.18 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.18-py3-none-any.whl (8.9 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.17-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.17 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.17-py3-none-any.whl (8.9 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.16-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.16 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.16-py3-none-any.whl (8.9 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.15-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.15 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.15-py3-none-any.whl (8.9 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.14-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.14 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.14-py3-none-any.whl (8.9 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.13-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.13 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.13-py3-none-any.whl (8.9 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.12-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.12 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.12-py3-none-any.whl (8.9 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.11-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.11 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.11-py3-none-any.whl (8.9 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.10-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.10 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.10-py3-none-any.whl (8.9 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.9-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.9 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.9-py3-none-any.whl (8.9 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.8-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.8 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.8-py3-none-any.whl (8.9 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.7-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.7 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.7-py3-none-any.whl (8.9 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.6-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.6 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.6-py3-none-any.whl (8.9 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.5-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.5 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.5-py3-none-any.whl (8.9 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.4-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.4 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.4-py3-none-any.whl (8.9 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.3-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.3 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.3-py3-none-any.whl (8.9 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.2-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.2 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.2-py3-none-any.whl (8.8 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.1-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.1 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.1-py3-none-any.whl (8.8 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.24.0-py3-none-any.whl (132 kB)
# Collecting botocore<1.28.0,>=1.27.0 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.27.0-py3-none-any.whl (8.8 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.23.10-py3-none-any.whl (132 kB)
# Collecting botocore<1.27.0,>=1.26.10 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.26.10-py3-none-any.whl (8.8 MB)
# Collecting s3transfer<0.6.0,>=0.5.0 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached s3transfer-0.5.2-py3-none-any.whl (79 kB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.23.9-py3-none-any.whl (132 kB)
# Collecting botocore<1.27.0,>=1.26.9 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.26.9-py3-none-any.whl (8.8 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.23.8-py3-none-any.whl (132 kB)
# Collecting botocore<1.27.0,>=1.26.8 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.26.8-py3-none-any.whl (8.8 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.23.7-py3-none-any.whl (132 kB)
# Collecting botocore<1.27.0,>=1.26.7 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.26.7-py3-none-any.whl (8.8 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.23.6-py3-none-any.whl (132 kB)
# Collecting botocore<1.27.0,>=1.26.6 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.26.6-py3-none-any.whl (8.8 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.23.5-py3-none-any.whl (132 kB)
# Collecting botocore<1.27.0,>=1.26.5 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.26.5-py3-none-any.whl (8.8 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.23.4-py3-none-any.whl (132 kB)
# Collecting botocore<1.27.0,>=1.26.4 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.26.4-py3-none-any.whl (8.8 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.23.3-py3-none-any.whl (132 kB)
# Collecting botocore<1.27.0,>=1.26.3 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.26.3-py3-none-any.whl (8.8 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.23.2-py3-none-any.whl (132 kB)
# Collecting botocore<1.27.0,>=1.26.2 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.26.2-py3-none-any.whl (8.8 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.23.1-py3-none-any.whl (132 kB)
# Collecting botocore<1.27.0,>=1.26.1 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.26.1-py3-none-any.whl (8.7 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.23.0-py3-none-any.whl (132 kB)
# Collecting botocore<1.27.0,>=1.26.0 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.26.0-py3-none-any.whl (8.7 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.22.13-py3-none-any.whl (132 kB)
# Collecting botocore<1.26.0,>=1.25.13 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.25.13-py3-none-any.whl (8.7 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.22.12-py3-none-any.whl (132 kB)
# Collecting botocore<1.26.0,>=1.25.12 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.25.12-py3-none-any.whl (8.7 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.22.11-py3-none-any.whl (132 kB)
# Collecting botocore<1.26.0,>=1.25.11 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.25.11-py3-none-any.whl (8.7 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.22.10-py3-none-any.whl (132 kB)
# Collecting botocore<1.26.0,>=1.25.10 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.25.10-py3-none-any.whl (8.7 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.22.9-py3-none-any.whl (132 kB)
# Collecting botocore<1.26.0,>=1.25.9 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.25.9-py3-none-any.whl (8.7 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.22.8-py3-none-any.whl (132 kB)
# Collecting botocore<1.26.0,>=1.25.8 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.25.8-py3-none-any.whl (8.7 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.22.7-py3-none-any.whl (132 kB)
# Collecting botocore<1.26.0,>=1.25.7 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.25.7-py3-none-any.whl (8.7 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.22.6-py3-none-any.whl (132 kB)
# Collecting botocore<1.26.0,>=1.25.6 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.25.6-py3-none-any.whl (8.7 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.22.5-py3-none-any.whl (132 kB)
# Collecting botocore<1.26.0,>=1.25.5 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.25.5-py3-none-any.whl (8.7 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.22.4-py3-none-any.whl (132 kB)
# Collecting botocore<1.26.0,>=1.25.4 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.25.4-py3-none-any.whl (8.7 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.22.3-py3-none-any.whl (132 kB)
# Collecting botocore<1.26.0,>=1.25.3 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.25.3-py3-none-any.whl (8.7 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.22.2-py3-none-any.whl (132 kB)
# Collecting botocore<1.26.0,>=1.25.2 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.25.2-py3-none-any.whl (8.7 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.22.1-py3-none-any.whl (132 kB)
# Collecting botocore<1.26.0,>=1.25.1 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.25.1-py3-none-any.whl (8.7 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.22.0-py3-none-any.whl (132 kB)
# Collecting botocore<1.26.0,>=1.25.0 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.25.0-py3-none-any.whl (8.7 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.21.46-py3-none-any.whl (132 kB)
# Collecting botocore<1.25.0,>=1.24.46 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.24.46-py3-none-any.whl (8.7 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.21.45-py3-none-any.whl (132 kB)
# Collecting botocore<1.25.0,>=1.24.45 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.24.45-py3-none-any.whl (8.7 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.21.44-py3-none-any.whl (132 kB)
# Collecting botocore<1.25.0,>=1.24.44 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.24.44-py3-none-any.whl (8.7 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.21.43-py3-none-any.whl (132 kB)
# Collecting botocore<1.25.0,>=1.24.43 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.24.43-py3-none-any.whl (8.7 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.21.42-py3-none-any.whl (132 kB)
# Collecting botocore<1.25.0,>=1.24.42 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.24.42-py3-none-any.whl (8.7 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.21.41-py3-none-any.whl (132 kB)
# Collecting botocore<1.25.0,>=1.24.41 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.24.41-py3-none-any.whl (8.7 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.21.40-py3-none-any.whl (132 kB)
# Collecting botocore<1.25.0,>=1.24.40 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.24.40-py3-none-any.whl (8.7 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.21.39-py3-none-any.whl (132 kB)
# Collecting botocore<1.25.0,>=1.24.39 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.24.39-py3-none-any.whl (8.7 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.21.38-py3-none-any.whl (132 kB)
# Collecting botocore<1.25.0,>=1.24.38 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.24.38-py3-none-any.whl (8.7 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.21.37-py3-none-any.whl (132 kB)
# Collecting botocore<1.25.0,>=1.24.37 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.24.37-py3-none-any.whl (8.7 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.21.36-py3-none-any.whl (132 kB)
# Collecting botocore<1.25.0,>=1.24.36 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.24.36-py3-none-any.whl (8.7 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.21.35-py3-none-any.whl (132 kB)
# Collecting botocore<1.25.0,>=1.24.35 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.24.35-py3-none-any.whl (8.7 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.21.34-py3-none-any.whl (132 kB)
# Collecting botocore<1.25.0,>=1.24.34 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.24.34-py3-none-any.whl (8.6 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.21.33-py3-none-any.whl (132 kB)
# Collecting botocore<1.25.0,>=1.24.33 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.24.33-py3-none-any.whl (8.6 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.21.32-py3-none-any.whl (132 kB)
# Collecting botocore<1.25.0,>=1.24.32 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.24.32-py3-none-any.whl (8.6 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.21.31-py3-none-any.whl (132 kB)
# Collecting botocore<1.25.0,>=1.24.31 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.24.31-py3-none-any.whl (8.6 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.21.30-py3-none-any.whl (132 kB)
# Collecting botocore<1.25.0,>=1.24.30 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.24.30-py3-none-any.whl (8.6 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.21.29-py3-none-any.whl (132 kB)
# Collecting botocore<1.25.0,>=1.24.29 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.24.29-py3-none-any.whl (8.6 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.21.28-py3-none-any.whl (132 kB)
# Collecting botocore<1.25.0,>=1.24.28 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.24.28-py3-none-any.whl (8.6 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.21.27-py3-none-any.whl (132 kB)
# Collecting botocore<1.25.0,>=1.24.27 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.24.27-py3-none-any.whl (8.6 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.21.26-py3-none-any.whl (132 kB)
# Collecting botocore<1.25.0,>=1.24.26 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.24.26-py3-none-any.whl (8.6 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.21.25-py3-none-any.whl (132 kB)
# Collecting botocore<1.25.0,>=1.24.25 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.24.25-py3-none-any.whl (8.6 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.21.24-py3-none-any.whl (132 kB)
# Collecting botocore<1.25.0,>=1.24.24 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.24.24-py3-none-any.whl (8.6 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.21.23-py3-none-any.whl (132 kB)
# Collecting botocore<1.25.0,>=1.24.23 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.24.23-py3-none-any.whl (8.6 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.21.22-py3-none-any.whl (132 kB)
# Collecting botocore<1.25.0,>=1.24.22 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.24.22-py3-none-any.whl (8.6 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.21.21-py3-none-any.whl (132 kB)
# Collecting botocore<1.25.0,>=1.24.21 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.24.21-py3-none-any.whl (8.6 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.21.20-py3-none-any.whl (132 kB)
# Collecting jmespath<1.0.0,>=0.7.1 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting botocore<1.25.0,>=1.24.20 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached botocore-1.24.20-py3-none-any.whl (8.6 MB)
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Using cached boto3-1.21.19-py3-none-any.whl (132 kB)
# ...
#   Downloading boto3-1.9.0-py2.py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.5/128.5 kB 16.8 MB/s eta 0:00:00
# Collecting botocore<1.13.0,>=1.12.0 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Downloading botocore-1.12.0-py2.py3-none-any.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 3.8 MB/s eta 0:00:00
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Downloading boto3-1.8.9-py2.py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.5/128.5 kB 16.8 MB/s eta 0:00:00
# Collecting botocore<1.12.0,>=1.11.9 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Downloading botocore-1.11.9-py2.py3-none-any.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 14.7 MB/s eta 0:00:00
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Downloading boto3-1.8.8-py2.py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.5/128.5 kB 15.6 MB/s eta 0:00:00
# Collecting botocore<1.12.0,>=1.11.8 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Downloading botocore-1.11.8-py2.py3-none-any.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 6.2 MB/s eta 0:00:00
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Downloading boto3-1.8.7-py2.py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.5/128.5 kB 15.7 MB/s eta 0:00:00
# Collecting botocore<1.12.0,>=1.11.7 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Downloading botocore-1.11.7-py2.py3-none-any.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 16.2 MB/s eta 0:00:00
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Downloading boto3-1.8.6-py2.py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.5/128.5 kB 15.9 MB/s eta 0:00:00
# Collecting botocore<1.12.0,>=1.11.6 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Downloading botocore-1.11.6-py2.py3-none-any.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 6.5 MB/s eta 0:00:00
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Downloading boto3-1.8.5-py2.py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.5/128.5 kB 15.6 MB/s eta 0:00:00
# Collecting botocore<1.12.0,>=1.11.5 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Downloading botocore-1.11.5-py2.py3-none-any.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 4.1 MB/s eta 0:00:00
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Downloading boto3-1.8.4-py2.py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.5/128.5 kB 16.7 MB/s eta 0:00:00
# Collecting botocore<1.12.0,>=1.11.4 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Downloading botocore-1.11.4-py2.py3-none-any.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 15.6 MB/s eta 0:00:00
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Downloading boto3-1.8.3-py2.py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.5/128.5 kB 16.4 MB/s eta 0:00:00
# Collecting botocore<1.12.0,>=1.11.3 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Downloading botocore-1.11.3-py2.py3-none-any.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 13.5 MB/s eta 0:00:00
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Downloading boto3-1.8.2-py2.py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.5/128.5 kB 16.9 MB/s eta 0:00:00
# Collecting botocore<1.12.0,>=1.11.2 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Downloading botocore-1.11.2-py2.py3-none-any.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 4.3 MB/s eta 0:00:00
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Downloading boto3-1.8.1-py2.py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.5/128.5 kB 16.2 MB/s eta 0:00:00
# Collecting botocore<1.12.0,>=1.11.1 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Downloading botocore-1.11.1-py2.py3-none-any.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 8.3 MB/s eta 0:00:00
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Downloading boto3-1.8.0-py2.py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.5/128.5 kB 14.6 MB/s eta 0:00:00
# Collecting botocore<1.12.0,>=1.11.0 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Downloading botocore-1.11.0-py2.py3-none-any.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 8.2 MB/s eta 0:00:00
# Collecting boto3 (from pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Downloading boto3-1.7.84-py2.py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.5/128.5 kB 17.4 MB/s eta 0:00:00
# Collecting botocore<1.11.0,>=1.10.84 (from boto3->pytorch-pretrained-bert->summ-eval~=0.892->crfm-helm)
#   Downloading botocore-1.10.84-py2.py3-none-any.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 112.6 MB/s eta 0:00:00
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.5.0->pycares>=4.0.0->aiodns>=3.0.0->aleph-alpha-client~=2.14.0->crfm-helm) (2.21)
# Building wheels for collected packages: pytrec-eval, gdown, pyext, pyhocon, rouge-score, sqlitedict, pyemd, uncertainty-calibration, undetected-chromedriver, moverscore, sacremoses, typing
#   Building wheel for pytrec-eval (setup.py) ... done
#   Created wheel for pytrec-eval: filename=pytrec_eval-0.5-cp310-cp310-linux_x86_64.whl size=308217 sha256=09cc7b3f3a84488ffc035362b91ce6769e1e0714801d011313ac31e88b9cf060
#   Stored in directory: /root/.cache/pip/wheels/51/3a/cd/dcc1ddfc763987d5cb237165d8ac249aa98a23ab90f67317a8
#   Building wheel for gdown (pyproject.toml) ... done
#   Created wheel for gdown: filename=gdown-4.4.0-py3-none-any.whl size=14758 sha256=2a50f2a6f1bb5c5a4de75934a97a98587192e9838d1487635144bf0d73d26051
#   Stored in directory: /root/.cache/pip/wheels/03/0b/3f/6ddf67a417a5b400b213b0bb772a50276c199a386b12c06bfc
#   Building wheel for pyext (setup.py) ... done
#   Created wheel for pyext: filename=pyext-0.7-py3-none-any.whl size=7222 sha256=30de67e74a7268842fa58b5e9d8fed0f791e239ba0e35cb6f35adb0752cf2f9a
#   Stored in directory: /root/.cache/pip/wheels/09/95/a9/f3f15c5e52dec7912c332ae503e82fd680e576bf336437f002
#   Building wheel for pyhocon (setup.py) ... done
#   Created wheel for pyhocon: filename=pyhocon-0.3.60-py3-none-any.whl size=20865 sha256=6b98c936da0d36c2b99a2c877e195bf41c104e5440241de156a103da2a6062b9
#   Stored in directory: /root/.cache/pip/wheels/32/79/47/98ab23fa895daa293e4dd4ce43e581c035ca15e908a2d94104
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24933 sha256=24b96664a5b404631e8cf8d634cda41b442d441f5455183446e07dd067dbc6b3
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
#   Building wheel for sqlitedict (setup.py) ... done
#   Created wheel for sqlitedict: filename=sqlitedict-1.7.0-py3-none-any.whl size=14390 sha256=7195773601beda80d0cf1d222a4807e3e536d80afc91c1c44bf0dc607a19707c
#   Stored in directory: /root/.cache/pip/wheels/86/8d/5f/8ad5a7e9be1c6774ccc0b832e0020b61e1f9b239491ddffffb
#   Building wheel for pyemd (setup.py) ... done
#   Created wheel for pyemd: filename=pyemd-0.5.1-cp310-cp310-linux_x86_64.whl size=506253 sha256=6e1e0e1ee01c5d01ad88c5cc7f5a966894c9fbcfb3c53bc346cdaaa5c073debe
#   Stored in directory: /root/.cache/pip/wheels/79/16/43/a541588b3c72f292471ecc780d2bf1a1f3c7a33141f4e2b1e8
#   Building wheel for uncertainty-calibration (setup.py) ... done
#   Created wheel for uncertainty-calibration: filename=uncertainty_calibration-0.1.4-py3-none-any.whl size=14201 sha256=8506daf8b5ab765b7a31742785289cf321e4406b8112a57a664d852fbea4cbeb
#   Stored in directory: /root/.cache/pip/wheels/9c/fb/74/93a4d13a3aa8e85f5f2b570114d0c19c7e1e1366f901c9d1c0
#   Building wheel for undetected-chromedriver (setup.py) ... done
#   Created wheel for undetected-chromedriver: filename=undetected_chromedriver-3.5.2-py3-none-any.whl size=47288 sha256=0bdf951a25f9337c1fca186f3545e4dc542bc80a0620a34244f03a1936e0e387
#   Stored in directory: /root/.cache/pip/wheels/bd/63/41/973b9953b807ccbd4075d06a6f94a07ee402419f291b81ed3f
#   Building wheel for moverscore (setup.py) ... done
#   Created wheel for moverscore: filename=moverscore-1.0.3-py3-none-any.whl size=7949 sha256=a63aaf1d21abc2e2e404e2767c848c321388d68f9e5102d253fc69d023ebe56b
#   Stored in directory: /root/.cache/pip/wheels/ae/b5/15/116944664c4dc1bc5316f63395d0ca11d325364b44112eb381
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895240 sha256=eea005583627b2988db31685d3e43c0387fc81b8b11edfc38d6e5d4804155ae5
#   Stored in directory: /root/.cache/pip/wheels/00/24/97/a2ea5324f36bc626e1ea0267f33db6aa80d157ee977e9e42fb
#   Building wheel for typing (setup.py) ... done
#   Created wheel for typing: filename=typing-3.7.4.3-py3-none-any.whl size=26307 sha256=6b5f9777abea1c12eba99fcc4c6f2f96647af867a4f7d46ed9d474905d3a6864
#   Stored in directory: /root/.cache/pip/wheels/7c/d0/9e/1f26ebb66d9e1732e4098bc5a6c2d91f6c9a529838f0284890
# Successfully built pytrec-eval gdown pyext pyhocon rouge-score sqlitedict pyemd uncertainty-calibration undetected-chromedriver moverscore sacremoses typing
# Installing collected packages: tls-client, sqlitedict, sentencepiece, pyext, bottle, zstandard, websockets, websocket-client, typing, tqdm, torch, sympy, simple-slurm, scipy, retrying, pytrec-eval, pymongo, pyhocon, pyemd, pydantic, pyarrow, portalocker, parameterized, outcome, jsonlines, jmespath, importlib-resources, h11, gunicorn, emoji, dill, dacite, colorama, cattrs, wsproto, trio, torchvision, tiktoken, surge-api, stanza, scikit-learn, scaleapi, sacremoses, sacrebleu, responses, pycares, multiprocess, moverscore, matplotlib, httpcore, botocore, 2captcha-python, uncertainty-calibration, trio-websocket, transformers, seaborn, s3transfer, rouge-score, openai, icetk, httpx, gdown, aiohttp-retry, aiodns, spacy, selenium, google-api-python-client, datasets, boto3, blanc, bert-score, anthropic, aleph-alpha-client, undetected-chromedriver, pytorch-pretrained-bert, summ-eval, revChatGPT, crfm-helm
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 1.6.1
#     Uninstalling websocket-client-1.6.1:
#       Successfully uninstalled websocket-client-1.6.1
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.1
#     Uninstalling tqdm-4.66.1:
#       Successfully uninstalled tqdm-4.66.1
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.1+cu118
#     Uninstalling torch-2.0.1+cu118:
#       Successfully uninstalled torch-2.0.1+cu118
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.12
#     Uninstalling sympy-1.12:
#       Successfully uninstalled sympy-1.12
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.10.1
#     Uninstalling scipy-1.10.1:
#       Successfully uninstalled scipy-1.10.1
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.2.0
#     Uninstalling pydantic-2.2.0:
#       Successfully uninstalled pydantic-2.2.0
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 9.0.0
#     Uninstalling pyarrow-9.0.0:
#       Successfully uninstalled pyarrow-9.0.0
#   Attempting uninstall: importlib-resources
#     Found existing installation: importlib-resources 6.0.1
#     Uninstalling importlib-resources-6.0.1:
#       Successfully uninstalled importlib-resources-6.0.1
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.7
#     Uninstalling dill-0.3.7:
#       Successfully uninstalled dill-0.3.7
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.15.2+cu118
#     Uninstalling torchvision-0.15.2+cu118:
#       Successfully uninstalled torchvision-0.15.2+cu118
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
#   Attempting uninstall: multiprocess
#     Found existing installation: multiprocess 0.70.15
#     Uninstalling multiprocess-0.70.15:
#       Successfully uninstalled multiprocess-0.70.15
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.31.0
#     Uninstalling transformers-4.31.0:
#       Successfully uninstalled transformers-4.31.0
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.12.2
#     Uninstalling seaborn-0.12.2:
#       Successfully uninstalled seaborn-0.12.2
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.6.6
#     Uninstalling gdown-4.6.6:
#       Successfully uninstalled gdown-4.6.6
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.6.1
#     Uninstalling spacy-3.6.1:
#       Successfully uninstalled spacy-3.6.1
#   Attempting uninstall: google-api-python-client
#     Found existing installation: google-api-python-client 2.84.0
#     Uninstalling google-api-python-client-2.84.0:
#       Successfully uninstalled google-api-python-client-2.84.0
#   Attempting uninstall: datasets
#     Found existing installation: datasets 2.14.4
#     Uninstalling datasets-2.14.4:
#       Successfully uninstalled datasets-2.14.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# en-core-web-sm 3.6.0 requires spacy<3.7.0,>=3.6.0, but you have spacy 3.5.4 which is incompatible.
# pandas-gbq 0.17.9 requires pyarrow<10.0dev,>=3.0.0, but you have pyarrow 11.0.0 which is incompatible.
# peft 0.4.0 requires torch>=1.13.0, but you have torch 1.12.1 which is incompatible.
# torchaudio 2.0.2+cu118 requires torch==2.0.1, but you have torch 1.12.1 which is incompatible.
# torchdata 0.6.1 requires torch==2.0.1, but you have torch 1.12.1 which is incompatible.
# torchtext 0.15.2 requires torch==2.0.1, but you have torch 1.12.1 which is incompatible.
# Successfully installed 2captcha-python-1.2.1 aiodns-3.0.0 aiohttp-retry-2.8.3 aleph-alpha-client-2.14.0 anthropic-0.2.10 bert-score-0.3.13 blanc-0.3.3 boto3-1.7.84 botocore-1.10.84 bottle-0.12.25 cattrs-22.2.0 colorama-0.4.6 crfm-helm-0.2.3 dacite-1.6.0 datasets-2.5.2 dill-0.3.5.1 emoji-2.8.0 gdown-4.4.0 google-api-python-client-2.64.0 gunicorn-20.1.0 h11-0.14.0 httpcore-0.17.3 httpx-0.24.1 icetk-0.0.4 importlib-resources-5.10.4 jmespath-0.10.0 jsonlines-3.1.0 matplotlib-3.6.3 moverscore-1.0.3 multiprocess-0.70.13 openai-0.27.9 outcome-1.2.0 parameterized-0.9.0 portalocker-2.7.0 pyarrow-11.0.0 pycares-4.3.0 pydantic-1.10.12 pyemd-0.5.1 pyext-0.7 pyhocon-0.3.60 pymongo-4.2.0 pytorch-pretrained-bert-0.6.2 pytrec-eval-0.5 responses-0.18.0 retrying-1.3.4 revChatGPT-0.1.1 rouge-score-0.1.2 s3transfer-0.1.13 sacrebleu-2.2.1 sacremoses-0.0.53 scaleapi-2.13.1 scikit-learn-1.1.3 scipy-1.9.3 seaborn-0.11.2 selenium-4.11.2 sentencepiece-0.1.99 simple-slurm-0.2.6 spacy-3.5.4 sqlitedict-1.7.0 stanza-1.5.0 summ-eval-0.892 surge-api-1.1.4 sympy-1.11.1 tiktoken-0.3.3 tls-client-0.2.1 torch-1.12.1 torchvision-0.13.1 tqdm-4.64.1 transformers-4.28.1 trio-0.22.2 trio-websocket-0.10.3 typing-3.7.4.3 uncertainty-calibration-0.1.4 undetected-chromedriver-3.5.2 websocket-client-1.3.3 websockets-11.0.3 wsproto-1.2.0 zstandard-0.18.0

# %%
# !helm-run --conf-paths run_specs.conf --suite v1 --max-eval-instances 10
# Out:
# 2023-08-23 23:18:25.405542: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# main {
#   Read 1 run entries from run_specs.conf
# } [0.014s]
# Traceback (most recent call last):
#   File "/usr/local/bin/helm-run", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.10/dist-packages/helm/common/hierarchical_logger.py", line 104, in wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/helm/benchmark/run.py", line 271, in main
#     run_specs = run_entries_to_run_specs(
#   File "/usr/local/lib/python3.10/dist-packages/helm/benchmark/run.py", line 38, in run_entries_to_run_specs
#     for run_spec in construct_run_specs(parse_object_spec(entry.description)):
#   File "/usr/local/lib/python3.10/dist-packages/helm/benchmark/run_specs.py", line 2310, in construct_run_specs
#     run_specs = [alter_run_spec(run_spec) for run_spec in run_specs]
#   File "/usr/local/lib/python3.10/dist-packages/helm/benchmark/run_specs.py", line 2310, in <listcomp>
#     run_specs = [alter_run_spec(run_spec) for run_spec in run_specs]
#   File "/usr/local/lib/python3.10/dist-packages/helm/benchmark/run_specs.py", line 2257, in alter_run_spec
#     model = get_model(run_spec.adapter_spec.model)
#   File "/usr/local/lib/python3.10/dist-packages/helm/proxy/models.py", line 824, in get_model
#     raise ValueError(f"No model with name: {model_name}")
# ValueError: No model with name: llama-2-7b-neurips_dm

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
model_name = "meta-llama/Llama-2-7b"
prompt = "Tell me about gravity"

#Replace by your Hugging Face access token (this is mine, revocated of course)
access_token = "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"


model = AutoModelForCausalLM.from_pretrained(model_name, device_map="auto", load_in_4bit=True,  use_auth_token=access_token)
tokenizer = AutoTokenizer.from_pretrained(model_name, use_fast=True, use_auth_token=access_token)
model_inputs = tokenizer(prompt, return_tensors="pt").to("cuda:0")


output = model.generate(**model_inputs)
print(tokenizer.decode(output[0], skip_special_tokens=True))
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:2193: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# Downloading (…)fetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-4dc5ccb7b206> in <cell line: 9>()
#       7
#       8
# ----> 9 model = AutoModelForCausalLM.from_pretrained(model_name, device_map="auto", load_in_4bit=True,  use_auth_token=access_token)
#      10 tokenizer = AutoTokenizer.from_pretrained(model_name, use_fast=True, use_auth_token=access_token)
#      11 model_inputs = tokenizer(prompt, return_tensors="pt").to("cuda:0")
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     491         elif type(config) in cls._model_mapping.keys():
#     492             model_class = _get_model_class(config, cls._model_mapping)
# --> 493             return model_class.from_pretrained(
#     494                 pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     495             )
#
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    2608         if is_sharded:
#    2609             # rsolved_archive_file becomes a list of files that point to the different checkpoint shards in this case.
# -> 2610             resolved_archive_file, sharded_metadata = get_checkpoint_shard_files(
#    2611                 pretrained_model_name_or_path,
#    2612                 resolved_archive_file,
#
# /usr/local/lib/python3.10/dist-packages/transformers/utils/hub.py in get_checkpoint_shard_files(pretrained_model_name_or_path, index_filename, cache_dir, force_download, proxies, resume_download, local_files_only, use_auth_token, user_agent, revision, subfolder, _commit_hash)
#     956         try:
#     957             # Load from URL
# --> 958             cached_filename = cached_file(
#     959                 pretrained_model_name_or_path,
#     960                 shard_filename,
#
# /usr/local/lib/python3.10/dist-packages/transformers/utils/hub.py in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, use_auth_token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash)
#     415     try:
#     416         # Load from URL or cache if already cached
# --> 417         resolved_file = hf_hub_download(
#     418             path_or_repo_id,
#     419             filename,
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     116             kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
#     117
# --> 118         return fn(*args, **kwargs)
#     119
#     120     return _inner_fn  # type: ignore
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, local_dir_use_symlinks, user_agent, force_download, force_filename, proxies, etag_timeout, resume_download, token, local_files_only, legacy_cache_layout)
#    1362             logger.info("downloading %s to %s", url, temp_file.name)
#    1363
# -> 1364             http_get(
#    1365                 url_to_download,
#    1366                 temp_file,
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py in http_get(url, temp_file, proxies, resume_size, headers, timeout, max_retries, expected_size)
#     542         if chunk:  # filter out keep-alive new chunks
#     543             progress.update(len(chunk))
# --> 544             temp_file.write(chunk)
#     545
#     546     if expected_size is not None and expected_size != temp_file.tell():
#
# /usr/lib/python3.10/tempfile.py in func_wrapper(*args, **kwargs)
#     620             @_functools.wraps(func)
#     621             def func_wrapper(*args, **kwargs):
# --> 622                 return func(*args, **kwargs)
#     623             # Avoid closing the file as long as the wrapper is alive,
#     624             # see issue #18879.
#
# KeyboardInterrupt:

# %%
while True:

  prompt = input()
  if prompt == "X":
    break
  model_inputs = tokenizer(prompt, return_tensors="pt").to("cuda:0")



  output = model.generate(**model_inputs)
  print(tokenizer.decode(output[0], skip_special_tokens=True))
# Out:
# X

# %%
max_input_length = tokenizer.max_model_input_sizes.get(model_name, None)

print(max_input_length)
# Out:
# None

# %%
from datasets import load_dataset
from transformers import  Trainer, TrainingArguments, DataCollatorForLanguageModeling


import os

os.environ["CUDA_LAUNCH_BLOCKING"] = "1"
os.environ["TORCH_USE_CUDA_DSA"] = "1"
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"

dataset = load_dataset("databricks/databricks-dolly-15k")

print(dataset)

print(type(dataset))

dataset = dataset.filter(lambda example: example["context"] is not None and example["instruction"] is not None)

tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right" # Fix weird overflow issue with fp16 training








# Tokenize the dataset
def tokenize_function(input):

    text =[context +"\n"+ instruction for context,instruction in zip(input["context"],input["instruction"])]
    return tokenizer(text, padding='max_length', truncation=True, max_length=4096)




tokenized_datasets = dataset.map(tokenize_function, batched=True)


for t in tokenized_datasets:
  print(len(t))


# Set the training arguments
training_args = TrainingArguments(
    output_dir="./llama_model",
    evaluation_strategy="epoch",
    num_train_epochs=3,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    logging_dir="./logs",
    logging_steps=1000,
)


# Define the Trainer

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["train"],
)

# Train the model
trainer.train()

# Save the trained model
model.save_pretrained("./sentiment_model")
tokenizer.save_pretrained("./sentiment_model")
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['instruction', 'context', 'response', 'category'],
#         num_rows: 15011
#     })
# })
# <class 'datasets.dataset_dict.DatasetDict'>
# Map:   0%|          | 0/15011 [00:00<?, ? examples/s]
# 5
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-7-eff6d04d5cc2> in <cell line: 59>()
#      57 # Define the Trainer
#      58
# ---> 59 trainer = Trainer(
#      60     model=model,
#      61     args=training_args,
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in __init__(self, model, args, data_collator, train_dataset, eval_dataset, tokenizer, model_init, compute_metrics, callbacks, optimizers, preprocess_logits_for_metrics)
#     329         self.args = args
#     330         # Seed must be set before instantiating the model when using model
# --> 331         enable_full_determinism(self.args.seed) if self.args.full_determinism else set_seed(self.args.seed)
#     332         self.hp_name = None
#     333         self.deepspeed = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer_utils.py in set_seed(seed)
#      92     np.random.seed(seed)
#      93     if is_torch_available():
# ---> 94         torch.manual_seed(seed)
#      95         torch.cuda.manual_seed_all(seed)
#      96         # ^^ safe to call this function even if cuda is not available
#
# /usr/local/lib/python3.10/dist-packages/torch/random.py in manual_seed(seed)
#      38
#      39     if not torch.cuda._is_in_bad_fork():
# ---> 40         torch.cuda.manual_seed_all(seed)
#      41
#      42     import torch.mps
#
# /usr/local/lib/python3.10/dist-packages/torch/cuda/random.py in manual_seed_all(seed)
#     111             default_generator.manual_seed(seed)
#     112
# --> 113     _lazy_call(cb, seed_all=True)
#     114
#     115
#
# /usr/local/lib/python3.10/dist-packages/torch/cuda/__init__.py in _lazy_call(callable, **kwargs)
#     181 def _lazy_call(callable, **kwargs):
#     182     if is_initialized():
# --> 183         callable()
#     184     else:
#     185         # TODO(torch_deploy): this accesses linecache, which attempts to read the
#
# /usr/local/lib/python3.10/dist-packages/torch/cuda/random.py in cb()
#     109         for i in range(device_count()):
#     110             default_generator = torch.cuda.default_generators[i]
# --> 111             default_generator.manual_seed(seed)
#     112
#     113     _lazy_call(cb, seed_all=True)
#
# RuntimeError: CUDA error: device-side assert triggered
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
